# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from tqdm.auto import tqdm

# %%
vacs = []
for i in tqdm(range(10)):
    url = f'https://my.sbertalents.ru/job-requisition/v2?page={i}&size=100'
    res = requests.get(url).json()
    if len(res['content']) > 0:
        vacs.extend(res['content'])
    else:
        break
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
res['content'][0]
# Out:
# {'schedule': None,
#  'content': {'title': 'Старший менеджер по обслуживанию',
#   'footer': '<p><strong>Мы предлагаем:</strong></p><p>\xa0</p><ul><li>трудоустройство согласно ТК РФ;</li><li>гарантированный доход плюс премиальное вознаграждение;</li><li>возможность работать рядом с домом/местом учебы;</li><li>регулярное корпоративное обучение;</li><li>ДМС, страхование от несчастных случаев и тяжелых заболеваний;</li><li>материальную помощь и социальную поддержку, корпоративную пенсионную программу;</li><li>льготные условия кредитования;</li><li>яркую и насыщенную корпоративную жизнь.</li></ul><p>\xa0</p><p><strong>Мы ждем тебя, чтобы строить счастливое будущее вместе!</strong></p>',
#   'header': '<p><span style="color:#ff0000">от 40 000 руб. до вычета НДФЛ</span></p><p>\xa0</p><p><strong>Если ты:</strong></p><p>\xa0</p><ul><li>хочешь работать в дружном коллективе;</li><li>стремишься к достижению лучших результатов для клиентов.</li></ul><p>\xa0</p><p><strong>Начни работу в крупнейшем банке России и СНГ!</strong></p><p>\xa0</p><p><strong>Как менеджер по обслуживанию, ты будешь: </strong></p><p>\xa0</p><ul><li>осуществлять операции по обслуживанию физических лиц;</li><li>проводить кассовые операции (прием/выдача/обмен денег).<br />\xa0</li></ul><p><strong>Ты подходишь нам, если ты:</strong></p><p>\xa0</p><ul><li>специалист со средним профессиональным/неполным высшим/высшим образованием;</li><li>владеешь программами Microsoft Office, Internet Explorer, Outlook;</li><li>внимателен к деталям;</li><li>готов к работе, предполагающей ежедневное проведение однотипных операций;</li><li>проявляешь доброжелательность, готовность оказывать помощь окружающим;</li><li>выдерживаешь высокий темп работы.</li></ul>',
#   'duties': '<p><span style="color:#ff0000">от 40 000 руб. до вычета НДФЛ</span></p><p>\xa0</p><p><strong>Если ты:</strong></p><p>\xa0</p><ul><li>хочешь работать в дружном коллективе;</li><li>стремишься к достижению лучших результатов для клиентов.</li></ul><p>\xa0</p><p><strong>Начни работу в крупнейшем банке России и СНГ!</strong></p><p>\xa0</p><p><strong>Как менеджер по обслуживанию, ты будешь: </strong></p><p>\xa0</p><ul><li>осуществлять операции по обслуживанию физических лиц;</li><li>проводить кассовые операции (прием/выдача/обмен денег).<br />\xa0</li></ul><p><strong>Ты подходишь нам, если ты:</strong></p><p>\xa0</p><ul><li>специалист со средним профессиональным/неполным высшим/высшим образованием;</li><li>владеешь программами Microsoft Office, Internet Explorer, Outlook;</li><li>внимателен к деталям;</li><li>готов к работе, предполагающей ежедневное проведение однотипных операций;</li><li>проявляешь доброжелательность, готовность оказывать помощь окружающим;</li><li>выдерживаешь высокий темп работы.</li></ul>',
#   'conditions': '<p><strong></strong></p><p>\xa0</p><ul><li>трудоустройство согласно ТК РФ;</li><li>гарантированный доход плюс премиальное вознаграждение;</li><li>возможность работать рядом с домом/местом учебы;</li><li>регулярное корпоративное обучение;</li><li>ДМС, страхование от несчастных случаев и тяжелых заболеваний;</li><li>материальную помощь и социальную поддержку, корпоративную пенсионную программу;</li><li>льготные условия кредитования;</li><li>яркую и насыщенную корпоративную жизнь.</li></ul><p>\xa0</p><p><strong>Мы ждем тебя, чтобы строить счастливое будущее вместе!</strong></p>'},
#  'date': '2020-11-25',
#  'postingCategory': 787,
#  'relocation': None,
#  'id': 78349,
#  'fullPartTime': None,
#  'locality': 8540,
#  'accessibility': [],
#  'region': 1504,
#  'company': 25765}

# %%
https://my.sbertalents.ru/#/job-requisition/78349

# %%
res.keys()
# Out:
# dict_keys(['content', 'pageable', 'totalPages', 'totalElements', 'last', 'number', 'size', 'numberOfElements', 'sort', 'first', 'empty'])

# %%
vacs[0]
# Out:
# {'schedule': None,
#  'content': {'title': 'Мобильный менеджер по продажам',
#   'footer': '<p>&nbsp;</p><p><strong>Мы предлагаем:</strong></p><p>&nbsp;</p><ul><li>оформление согласно трудовому кодексу РФ</li><li>оклад плюс система премий по результатам работы (ежемесячная и годовая премии)</li><li>ДМС и материальная поддержка</li><li>корпоративное обучение</li><li>профессиональный и карьерный рост</li><li>яркая и насыщенная корпоративная жизнь (праздники, соревнования, спортивные мероприятия)</li><li>скидки на продукты Сбербанка и экосистемы</li></ul><p>&nbsp;</p><p><strong>Работая в Сбербанке, ты меняешь жизнь людей вокруг себя к лучшему!</strong></p>',
#   'header': '<p><strong>Мобильный менеджер по продажам</strong></p><p>&nbsp;</p><p>Задача мобильного менеджера ― продавать продукты Сбербанка через планшет и терминалы самообслуживания. Эта должность подойдет тем, кто готов к работе на &laquo;ногах&raquo;, открыт к новому и нацелен на развитие в продажах.</p><p>Если хочешь овладеть навыком эффективных продаж и не останавливаться на достигнутом, то работа мобильного менеджера по продажам в Сбербанке точно для тебя. Перед тобой открыты возможности вертикального и горизонтального развития: рост по карьерной лестнице или переход в другие отделения и города.</p><p>Присоединяйся к нашей команде Сбербанка!</p><p>&nbsp;</p><p><strong>Задачи:</strong></p><p>&nbsp;</p><ul><li>продавать продукты банка и экосистемы</li><li>помогать клиентам оформлять услуги на планшете, личном устройстве клиента или на устройстве самообслуживания в офисе банка</li></ul><p>&nbsp;</p><p><strong>Ждем от кандидата:</strong></p><p>&nbsp;</p><ul><li>образование от общего среднего</li><li>опыт работы в сфере услуг от 3 месяцев</li><li>грамотная и чистая речь</li><li>умение прояснять потребности клиента и вовлекать в диалог</li><li>устойчивость к возражениям и способность находить аргументы</li><li>ориентация на клиента и умение предлагать лучшие для него решения</li><li>амбициозность и желание совершенствоваться в продажах</li></ul>',
#   'duties': '<p><strong>Мобильный менеджер по продажам</strong></p><p>&nbsp;</p><p>Задача мобильного менеджера ― продавать продукты Сбербанка через планшет и терминалы самообслуживания. Эта должность подойдет тем, кто готов к работе на &laquo;ногах&raquo;, открыт к новому и нацелен на развитие в продажах.</p><p>Если хочешь овладеть навыком эффективных продаж и не останавливаться на достигнутом, то работа мобильного менеджера по продажам в Сбербанке точно для тебя. Перед тобой открыты возможности вертикального и горизонтального развития: рост по карьерной лестнице или переход в другие отделения и города.</p><p>Присоединяйся к нашей команде Сбербанка!</p><p>&nbsp;</p><p><strong>Задачи:</strong></p><p>&nbsp;</p><ul><li>продавать продукты банка и экосистемы</li><li>помогать клиентам оформлять услуги на планшете, личном устройстве клиента или на устройстве самообслуживания в офисе банка</li></ul><p>&nbsp;</p><p><strong>Ждем от кандидата:</strong></p><p>&nbsp;</p><ul><li>образование от общего среднего</li><li>опыт работы в сфере услуг от 3 месяцев</li><li>грамотная и чистая речь</li><li>умение прояснять потребности клиента и вовлекать в диалог</li><li>устойчивость к возражениям и способность находить аргументы</li><li>ориентация на клиента и умение предлагать лучшие для него решения</li><li>амбициозность и желание совершенствоваться в продажах</li></ul>',
#   'conditions': '<p>&nbsp;</p><p><strong></strong></p><p>&nbsp;</p><ul><li>оформление согласно трудовому кодексу РФ</li><li>оклад плюс система премий по результатам работы (ежемесячная и годовая премии)</li><li>ДМС и материальная поддержка</li><li>корпоративное обучение</li><li>профессиональный и карьерный рост</li><li>яркая и насыщенная корпоративная жизнь (праздники, соревнования, спортивные мероприятия)</li><li>скидки на продукты Сбербанка и экосистемы</li></ul><p>&nbsp;</p><p><strong>Работая в Сбербанке, ты меняешь жизнь людей вокруг себя к лучшему!</strong></p>'},
#  'date': '2020-12-03',
#  'postingCategory': 788,
#  'relocation': None,
#  'id': 337818,
#  'fullPartTime': None,
#  'locality': 7839,
#  'accessibility': [],
#  'region': 1455,
#  'company': 25765}

# %%
def get_vacinfo(vhtml):
    vactext = ''
    vactitle = ''
    for k, v in vhtml.items():
        if k !='title':
            vactext += v
        else:
            vactitle = v
    soup = BeautifulSoup(vactext)
    vacdesc = soup.text.replace('\xa0',' ')
    return vactitle, vacdesc

# %%
vacs_dict = {
    'title':[],
    'description':[],
    'date':[],
    'id':[]
}

for vaca in tqdm(vacs):
    vtit, vdes = get_vacinfo(vaca['content'])
    vacs_dict['title'].append(vtit)
    vacs_dict['description'].append(vdes)
    vacs_dict['date'].append(vaca.get('date'))
    vacs_dict['id'].append(vaca['id'])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3260.0), HTML(value='')))

# %%
vtab = pd.DataFrame(vacs_dict)

# %%
vtab.head()
# Out:
#                             title  \
# 0  Мобильный менеджер по продажам
# 1   Специалист по прямым продажам
# 2   Специалист по прямым продажам
# 3  Мобильный менеджер по продажам
# 4  Мобильный менеджер по продажам
#
#                                          description        date      id
# 0  Мы предлагаем:оформление согласно трудовому ко...  2020-11-24  395814
# 1  Мы предлагаем: трудоустройство согласно ТК РФ;...  2020-11-23  452801
# 2  Мы предлагаем:  дистанционное обучение по банк...  2020-11-24  453517
# 3  Мы предлагаем: - оформление согласно трудовому...  2020-11-24  457243
# 4  Мы предлагаем:- оформление согласно трудовому ...  2020-11-24  460664

# %%
vtab[vtab.description.str.contains('python|Python')]
# Out:
#                                                   title  \
# 37                                 Продуктовый аналитик
# 39                       Старший эксперт по технологиям
# 40    Старший инженер информационной безопасности банка
# 43          Старший инженер информационной безопасности
# 46                                       DevOps инженер
# ...                                                 ...
# 3073                       Python (Голосовой ассистент)
# 3074                                   Java разработчик
# 3157                             Аналитик Витрин Данных
# 3171                                  Менеджер проектов
# 3234                                       Data инженер
#
#                                             description        date       id
# 37    Условия:Конкурентоспособный уровень дохода (ок...  2020-11-23  1451548
# 39    Работа у нас — это:Команда профессионалов, гот...  2020-11-24  1457214
# 40    Мы предлагаем:работа в крупнейшем банке России...  2020-11-23  1459802
# 43    Условия: работа в крупнейшем банке России;труд...  2020-11-23  1462871
# 46    Мы – большая, дружная команда, автоматизирующа...  2020-11-24  1462947
# ...                                                 ...         ...      ...
# 3073  ЦЕЛИ И ЗАДАЧИ:Разработка серверной части высок...  2020-05-14  1163658
# 3074  Machine Learning Engineer/Python разработчик К...  2020-05-13  1169089
# 3157  Условия: работа в крупнейшем банке России;труд...  2020-01-13   777257
# 3171  Ключевые навыки:Опыт проведения функциональног...  2019-12-18   999606
# 3234  Условия: работа в крупнейшем банке России;труд...  2019-04-01   501847
#
# [376 rows x 4 columns]

# %%
pat1 = 'python|Python'
pat2 = 'senior|Senior|руководитель|Руководитель|Главный|Директор'
t1 = vtab.description.str.contains(pat1)
t2 = vtab.title.str.contains(pat2)
# vtab[t1 & t2].title.tolist()

# %%
data = []

# %%
smlist = []
litr = iter([row['id'] for _, row in vtab[t1 & t2].iterrows()])

# %%
lrows = [row['id'] for _, row in vtab[t1 & t2].iterrows()]

# %%
def previous_current_next(iterable):
    """Создает итератор который выдает таплы (предыдущий, текущий, следующий)
    
    Если нет значения, то значения предыдущего или следующего, то возвращает None

    """
    iterable=iter(iterable)
    prv = None
    cur = next(iterable)
    try:
        while True:
            nxt = next(iterable)
            yield (prv,cur,nxt)
            prv = cur
            cur = nxt
    except StopIteration:
        yield (prv,cur,None)

# %%
class VacNavigator:
    
    def __init__(self, vactuple):
        self.current_id = vactuple[1]
        self.previous_id = vactuple[0]
        self.next_id = vactuple[2]

# %%
    vac_navis = [VacNavigator(tup) for tup in list(previous_current_next(lrows))]
    vac_navis_dict = {v.current_id :v for v in vac_navis}

# %%
vac_navis_dict.get(1465482).next_id
# Out:
# 1383390

# %%
def get_id_navigation(vac_id):
    return vac_navis_dict.get(vac_id)

# %%
vnav = get_id_navigation(1465482)
vnav.next_id
# Out:
# 1383390

# %%
vnav.previous_id

# %%
import sys
sys.path.extend(['../'])
from data.config import conn_string
from db.models import DataAccessLayer, Vacancy
# conn_string

# %%
dal = DataAccessLayer(conn_string)
dal.connect()
# dal.session.
# dal.session.bulk_save_objects(vacancy_objects)
# dal.session.commit()

# %%
dal = DataAccessLayer(conn_string)
dal.connect()

# %%
list_of_vacs = [x[0] for x in dal.session.query(Vacancy.vacid).all()]
len(list_of_vacs)
# Out:
# 1855

# %%
list_of_vacs = dal.session.query(Vacancy.vacid).filter(Vacancy.vactitle.op('~')(r"python|Руководитель")).all()

# %%
# list_of_vacs
vac = dal.session.query(Vacancy).filter_by(vacid=list_of_vacs[9]).first()

# %%
vac.vachtml.keys()
# Out:
# dict_keys(['title', 'footer', 'header', 'requirements', 'duties', 'conditions'])

# %%
vac.vachtml.get('title')
# Out:
# 'Руководитель службы охраны труда'

# %%
def get_txt_data(page):
    soup = BeautifulSoup(page)
    parsing_tag = None
    if len(soup.find_all('li')) > len(soup.find_all('p')):
        parsing_tag = 'li'
    elif len(soup.find_all('li')) < len(soup.find_all('p')):
        parsing_tag = 'li'

    if parsing_tag == 'li':
        return [x.text.replace('\xa0',' ') + '\n' for x in soup.find_all('li')]
    elif parsing_tag == 'p':
        return [x.text.replace('\xa0',' ') + '\n' for x in soup.find_all('p')]
    else :
        return soup.text

# %%
vac.vachtml.get('title')
# Out:
# 'Руководитель службы охраны труда'

# %%
for k, v in vac.vachtml.items():
    if k == 'title':
        continue
    print('*'*10, k, '*'*10)
    for line in get_txt_data(v):
        print(line, end='')
# Out:
# ********** footer **********
# Работа в команде профессионалов;
# Трудоустройство согласно ТК РФ;
# Регулярное корпоративное обучение;
# ДМС, страхование от несчастных случаев и тяжелых заболеваний;
# Материальная помощь и социальная поддержка, корпоративная пенсионная программа;
# Льготные условия кредитования;
# Яркая и насыщенная корпоративная жизнь.
# ********** header **********
# Создание с нуля системы охраны труда и пожарной безопасности в компании;
# Обеспечение экспертной оценки по вопросам охраны труда и техники безопасности;
# Создание условий, при которых все руководители и сотрудники будут обучены и аттестованы по необходимым дисциплинам и стандартам;
# Создание обстановки, в которой безопасности уделяется должное внимание;
# Обеспечение консультаций по вопросам охраны здоровья в тех случаях, где они пересекаются с вопросами охраны труда и пожарной безопасности;
# Управление взаимоотношениями между Компанией и Государственной инспекцией по труду, органами, обеспечивающими экспертизу по условиям труда и другими внешними организациями в области охраны труда, промышленной безопасности ГOиЧС и экологии;
# Подготовка документов в области охраны труда и пожарной безопасности в соответствии с требованиями компании и надзорных органов и в соответствии с законодательством.
# Высшее образование по направлению подготовки «Техносферная безопасность» или соответствующим ему направлениям подготовки (специальностям) по обеспечению безопасности производственной деятельности, либо высшее образование и дополнительное профессиональное образование (профессиональная переподготовка) в области охраны труда, либо среднее профессиональное образование и дополнительное профессиональное образование (профессиональная переподготовка) в области охраны труда;
# Повышение квалификации и профессиональной переподготовки по направлениям профессиональной деятельности в области охраны труда, промышленной, пожарной и экологической безопасности;
# Стаж работы в области охраны труда, промышленной, пожарной и экологической безопасности не менее 5 лет.
# ********** requirements **********
# Высшее образование по направлению подготовки «Техносферная безопасность» или соответствующим ему направлениям подготовки (специальностям) по обеспечению безопасности производственной деятельности, либо высшее образование и дополнительное профессиональное образование (профессиональная переподготовка) в области охраны труда, либо среднее профессиональное образование и дополнительное профессиональное образование (профессиональная переподготовка) в области охраны труда;
# Повышение квалификации и профессиональной переподготовки по направлениям профессиональной деятельности в области охраны труда, промышленной, пожарной и экологической безопасности;
# Стаж работы в области охраны труда, промышленной, пожарной и экологической безопасности не менее 5 лет.
# ********** duties **********
# Создание с нуля системы охраны труда и пожарной безопасности в компании;
# Обеспечение экспертной оценки по вопросам охраны труда и техники безопасности;
# Создание условий, при которых все руководители и сотрудники будут обучены и аттестованы по необходимым дисциплинам и стандартам;
# Создание обстановки, в которой безопасности уделяется должное внимание;
# Обеспечение консультаций по вопросам охраны здоровья в тех случаях, где они пересекаются с вопросами охраны труда и пожарной безопасности;
# Управление взаимоотношениями между Компанией и Государственной инспекцией по труду, органами, обеспечивающими экспертизу по условиям труда и другими внешними организациями в области охраны труда, промышленной безопасности ГOиЧС и экологии;
# Подготовка документов в области охраны труда и пожарной безопасности в соответствии с требованиями компании и надзорных органов и в соответствии с законодательством.
# ********** conditions **********
# Работа в команде профессионалов;
# Трудоустройство согласно ТК РФ;
# Регулярное корпоративное обучение;
# ДМС, страхование от несчастных случаев и тяжелых заболеваний;
# Материальная помощь и социальная поддержка, корпоративная пенсионная программа;
# Льготные условия кредитования;
# Яркая и насыщенная корпоративная жизнь.

# %%
def make_msg_pack(vac_desc):
    msg = []
    msg_pack = []
    for line in vac_desc.split(';'):
        if len('\n'.join(msg))  < 500:
            msg.append(line)
        else:
            msg_pack.append('\n'.join(msg))
            msg = []
    return msg_pack

# %%
num = 20
vac = dal.session.query(Vacancy).filter_by(vacid=list_of_vacs[num]).first()
msg_pack = make_msg_pack(vac.vacdescription)
print(vac.vactitle)
for el in msg_pack:
    print(el, end='\n============')
# Out:
# Руководитель контент-группы
# Условия:работа в крупнейшем банке России с активно развивающимся digital-направлением
# конкурентная заработная плата
# трудоустройство согласно ТК РФ
# рабочее место: г. Санкт-Петербург, м. Нарвская
# регулярное корпоративное обучение
# ДМС, страхование от несчастных случаев и тяжелых заболеваний
# льготные условия кредитования
# яркая и насыщенная корпоративная жизнь
# материальная помощь и социальная поддержка, корпоративная пенсионная программа.В лаборатории по исследованию клиентского опыта открыта вакансия руководителя контент-группы. Вам предстоит управлять процессом создания разноформатного контента «под ключ», осуществлять руководство креативной командой, планировать и распределять нагрузку на участников команды, участвовать в их развитии и обучении, достигать поставленных целей и нести ответственность за результат.Идеальный руководитель контент-группы – опытный редактор и менеджер, способный качественно выполнять поставленные задачи, ставить и достигать амбициозных целей, нести личную ответственность за результат команды. Обязанности:управлять креативной командой (дизайнер, верстальщик)
# ============контролировать подготовку контента от брифа до передачи материалов заказчику, редактировать и согласовывать разработанные материалы
# самостоятельно разрабатывать текстовое наполнение коммуникаций
# разрабатывать новые креативные решения в коммуникациях и улучшения ключевых метрик эффективности
# контролировать использование гайдлайна, брендбука, ред. политики и других правил и руководств
# контролировать ключевые метрики эффективности коммуникаций
# формировать концепции и планы, презентовать результаты работы. Требования:высшее образование (журналистика, связи с общественностью, филология)
# ============опыт работы редактором в федеральных онлайн-изданиях/ руководителем группы
# развитое чувство вкуса, понимания качества и потенциала креатива, знание современного рынка онлайн-рекламы, трендов в копирайтинге и графическом дизайне
# высокий уровень самоорганизации, умение работать с большими потоками информации в режиме многозадачности
# превосходные коммуникативные и презентационные навыки, умение вести переговоры
# навыки кросс-функционального взаимодействия
# лидерские качества, умение работать в команде
# ============опыт руководства командой от 3х лет
# опыт работы редактором в федеральных онлайн-изданиях/ руководителем группы
# развитое чувство вкуса, понимания качества и потенциала креатива, знание современного рынка онлайн-рекламы, трендов в копирайтинге и графическом дизайне
# высокий уровень самоорганизации, умение работать с большими потоками информации в режиме многозадачности
# превосходные коммуникативные и презентационные навыки, умение вести переговоры
# навыки кросс-функционального взаимодействия
# лидерские качества, умение работать в команде
# ============управлять процессом производства контента, обеспечивать достаточную скорость и регулярность в рамках контент-плана (преимущественно для каналов email, sms, IVR, story, push)
# контролировать подготовку контента от брифа до передачи материалов заказчику, редактировать и согласовывать разработанные материалы
# самостоятельно разрабатывать текстовое наполнение коммуникаций
# разрабатывать новые креативные решения в коммуникациях и улучшения ключевых метрик эффективности
# контролировать использование гайдлайна, брендбука, ред. политики и других правил и руководств
# ============

# %%
for el in msg_pack:
    print(el, end='')
# Out:
# Условия:работа в крупнейшем банке России с активно развивающимся digital-направлением
# конкурентная заработная плата
# трудоустройство согласно ТК РФ
# рабочее место: г. Санкт-Петербург, м. Нарвская
# регулярное корпоративное обучение
# ДМС, страхование от несчастных случаев и тяжелых заболеваний
# льготные условия кредитования
# яркая и насыщенная корпоративная жизнь
# материальная помощь и социальная поддержка, корпоративная пенсионная программа.В лаборатории по исследованию клиентского опыта открыта вакансия руководителя контент-группы. Вам предстоит управлять процессом создания разноформатного контента «под ключ», осуществлять руководство креативной командой, планировать и распределять нагрузку на участников команды, участвовать в их развитии и обучении, достигать поставленных целей и нести ответственность за результат.Идеальный руководитель контент-группы – опытный редактор и менеджер, способный качественно выполнять поставленные задачи, ставить и достигать амбициозных целей, нести личную ответственность за результат команды. Обязанности:управлять креативной командой (дизайнер, верстальщик)контролировать подготовку контента от брифа до передачи материалов заказчику, редактировать и согласовывать разработанные материалы
# самостоятельно разрабатывать текстовое наполнение коммуникаций
# разрабатывать новые креативные решения в коммуникациях и улучшения ключевых метрик эффективности
# контролировать использование гайдлайна, брендбука, ред. политики и других правил и руководств
# контролировать ключевые метрики эффективности коммуникаций
# формировать концепции и планы, презентовать результаты работы. Требования:высшее образование (журналистика, связи с общественностью, филология)опыт работы редактором в федеральных онлайн-изданиях/ руководителем группы
# развитое чувство вкуса, понимания качества и потенциала креатива, знание современного рынка онлайн-рекламы, трендов в копирайтинге и графическом дизайне
# высокий уровень самоорганизации, умение работать с большими потоками информации в режиме многозадачности
# превосходные коммуникативные и презентационные навыки, умение вести переговоры
# навыки кросс-функционального взаимодействия
# лидерские качества, умение работать в командеопыт руководства командой от 3х лет
# опыт работы редактором в федеральных онлайн-изданиях/ руководителем группы
# развитое чувство вкуса, понимания качества и потенциала креатива, знание современного рынка онлайн-рекламы, трендов в копирайтинге и графическом дизайне
# высокий уровень самоорганизации, умение работать с большими потоками информации в режиме многозадачности
# превосходные коммуникативные и презентационные навыки, умение вести переговоры
# навыки кросс-функционального взаимодействия
# лидерские качества, умение работать в командеуправлять процессом производства контента, обеспечивать достаточную скорость и регулярность в рамках контент-плана (преимущественно для каналов email, sms, IVR, story, push)
# контролировать подготовку контента от брифа до передачи материалов заказчику, редактировать и согласовывать разработанные материалы
# самостоятельно разрабатывать текстовое наполнение коммуникаций
# разрабатывать новые креативные решения в коммуникациях и улучшения ключевых метрик эффективности
# контролировать использование гайдлайна, брендбука, ред. политики и других правил и руководств

# %%
page = vac.vachtml.get('conditions')
soup = BeautifulSoup(page)
len(soup.text)
[x.text.replace('\xa0',' ') + '\n' for x in soup.find_all('li')]
# Out:
# ['комфортные условия работы: современный офис в центре города, бессрочный трудовой договор, пятидневную рабочую неделю;\n',
#  'достойное вознаграждение и возможность влиять на размер премиальной части заработной платы;\n',
#  'заботу о здоровье: корпоративную программу ДМС (включает стоматологию, обследования, лечение заболеваний и т.д.), бесплатный тренажерный зал, страхование жизни и много других мероприятий;\n',
#  'знания: огромная база знаний и дистанционных курсов, возможность обучения на очных программах, обмен опытом с коллегами и экспертная поддержка руководителей; доступ к конференциям и семинарам с известными мировыми спикерами по актуальным темам;\n',
#  'корпоративные мероприятия и праздники, волонтерскую активность;\n',
#  'особые условия для сотрудников: льготные условия кредитования, специальные курсы обмена валюты, дисконт-программы от партнеров банка.\n']

# %%
soup.text
# Out:
# '\xa0Мы предлагаем:комфортные условия работы: современный офис в центре города, бессрочный трудовой договор, пятидневную рабочую неделю;достойное вознаграждение\xa0и возможность влиять на размер премиальной части заработной платы;заботу о здоровье:\xa0корпоративную программу ДМС (включает стоматологию, обследования, лечение заболеваний и т.д.), бесплатный тренажерный зал, страхование жизни и много других мероприятий;знания:\xa0огромная база знаний и дистанционных курсов, возможность обучения на очных программах, обмен опытом с коллегами и экспертная поддержка руководителей; доступ к конференциям и семинарам с известными мировыми спикерами по актуальным темам;корпоративные мероприятия\xa0и праздники, волонтерскую активность;особые условия для сотрудников:\xa0льготные условия кредитования, специальные курсы обмена валюты, дисконт-программы от партнеров банка.Почему Сбер?\xa0Передовая компания. Современные технологии. Интересные задачи. Привлекательные условия. Возможности роста. Если вам нравится идея статья частью «главного» банка России, будем\xa0рады увидеть вас в команде!'

# %%
# vac.vachtml.get('duties')

# %%
# dal.session.query(Vacancy).filter_by(vacid=list_of_vacs[]).first()
# Out:
# Руководитель проектов В команду Управление интеграционных решений ДЗО(дочерние организации) и Экосистемы требуется руководитель направления.Успешный кандидат будет отвечать за тираж и развитие применения сервисов Объединяющих элементов (ОЭ) экосистемы Сбера в Блоке УБ: как в ДЗО так и в продуктах трайбов.Сервисы Объединяющих элементов (по-другому Энейблеров) продолжат расти с 16 в 2020 до 25 в 2021. С одной стороны, увеличивается количество функций бизнеса, которые берут на себя Энейблеры, разгружая ресурсы ДЗО, а с другой развивается функционал уже работающих ОЭ.Непосредственной реализаций подключения Энейблеров занимаются команды ДЗО и самих ОЭ. Учитывая масштаб экосистемы (80+ ДЗО), количество ОЭ (25+) и многочисленные задачи, которые приходится решать впервые в молодой экосистеме Сбера крайне необходимы специалисты, которые выстроят коммуникацию, скоординирует многочисленные команды и планы, будут накапливать и переносить опыт внутри Экосистемы. Именно таких специалистов мы ищем.В своей работе необходимо будет искать решение, учитывать интересы ДЗО и команд ОЭ, отдельных служб ДЗО и Банка, но при в первую очередь учитывать ценность результата для экосистемы Сбера в целом.Функциональные обязанности:Изучать технологические сервисах Объединяющих Элементов, подключаться к задачам интеграции для решения наиболее сложных проектных вопросов.Исследовать процессы и продукты ДЗО УБ для выявления потенциала применения сервисы ОЭСовместно с ДЗО и командами ОЭ формировать планы интеграции ОЭУчаствовать в качестве эксперта в задачах\проектах связанных с применением ОЭ, переносить опыт внедрения ОЭ на новые задачи подключения ОЭОрганизовывать на регулярной основе обзоры функционала и планов развития ОЭ для заинтересованных участников блока УБРегулярно обновлять детальный статус исполнения планов и презентацию с дорожной картой по применению и тиражу ОЭ в Блоке УБРаспространять практику применения и интеграции ОЭ для внутренних заказчиков блока, наработанную как в ДЗО УБ, так и в ДЗО ЭкосистемыФормировать реестр требований и доработок ОЭ в интересах и по заказу ДЗО УБ, отслеживать статус реализацииПостоянно углублять экспертизу в технологиях реализации ОЭ: SberNLP, SberCloud, SberApiRegistry, SberDataExchange, SberRadar, SberID, SberProfile и др.Помогать выстраивать коммуникации службам ДЗО и командам Банка ответственным за ОЭ при запуске и входе реализации подключения ОЭ: как в технологических вопросах, так и в вопросах договорных отношений, информационной безопасности и пр.Взаимодействовать с командами Энейблеров для формирования единого представления о статусе, планах запуска энейблеров с точки зрения потребностей Блока УБФормирование и актуализация дорожной карты  интеграции ДЗО УБ и трайбов в Экосистему, определение требований к готовности Энейблеров для применения в УБВзаимодействие с solution архитекторами ДЗО и трайбов для учета в архитектурах целевых функций, реализуемых Энейблерами.Основные задачи: Сбор, изучение и анализ документов по ЭнейблерамИнициация создания рабочих групп, согласование с владельцами выделения ресурсовПроведение и формализация результатов встреч, посвященных задачам подключения ОЭ в БлокеПодготовка и предоставление справочных материалов, коротких презентаций по Энейблерам по запросам заказчиков внутри БлокаОрганизация семинаров с обзором функционала и планов развития от команд ОЭ для заказчиков внутри Блока – ДЗО и трайбыПодготовка и обновление детального статуса и презентации по Дорожной карте и планам подключения\интеграции с ОЭРегулярное взаимодействие с сотрудниками ДЗО и трайбов уровня владельцев продукта и кластер лидов, ИТ-директоров по выявлению потенциальных процессов и продуктов, в которых применение ОЭ принесет наибольшую пользуПроведение встреч с представителями дирекций СберХ B2B, СберХ B2C, Технологической готовности, ДЗО Экосистемы, не относящимися к УБ в целях обмена опытом, синхронизации планов, референсо обзоров.Формирование единого понимание статуса и планов по ОЭ, распространение информа ...

# %%
list_of_vacs = [x[0] for x in list_of_vacs]
len(list_of_vacs)
# Out:
# 80

# %%
# def get_vacany_
def get_vacancy_obj(vac_id):
    dal = DataAccessLayer(conn_string)
    dal.connect()
    vobj = dal.session.query(Vacancy).filter(Vacancy.vacid == vac_id).first()
    return vobj

# %%
# # vac_id = list_of_vacs[3]
# for vac_id in list_of_vacs:
#     vob = get_vacancy_obj(vac_id)
#     print(vob.vactitle)

# %%
# vob.vactitle

# %%
vobj.vactitle

# %%
class VacancyMessage:
    def __init__(self, vobj):
        self.vacdescription = vobj.vacdescription
        self.title  = vobj.vactitle
        self.vac_id = vobj.vacid
    
    def make_message(self):
        return (self.title, self.vacdescription, self.vac_id)

# %%
# vm = VacancyMessage(vobj)
# vm.make_message()
# Out:
# ('Консультант по работе с ПФР',
#  'Мы предлагаем:- трудоустройство согласно ТК РФ;- гарантированный доход плюс премиальное вознаграждение;- регулярное корпоративное обучение;- ДМС, страхование от несчастных случаев и тяжелых заболеваний;- материальную помощь и социальную поддержку, корпоративную пенсионную программу;- льготные условия кредитования;- яркую и насыщенную корпоративную жизнь.Как специалист, ты будешь:- обеспечивать выполнение плана по привлечению пенсионеров на получение пенсии через Сбербанк,- консультировать пенсионеров в закрепленном отделении Пенсионного фонда России по услуге получения пенсии через Сбербанк;- оформлять заявления /заявки на открытие счета карты Сбербанк-Maestro Социальная для пенсионера.  Ты подходишь нам, если ты:- имеешь среднее/среднее профессиональное/неполное высшее/высшее образование;- желателен опыт работы с клиентами;- владеешь стандартным ПО (Microsoft Excel, Outlook)на уровне базовых операций. Личные качества:- умение самостоятельно устанавливать контакт с незнакомыми людьми;- легкость, уверенность и доброжелательность в общении;- ориентация на клиента, готовность проконсультировать, оказать помощь;- стремление к достижениям в работе, связанной с продажами, к получению дохода в зависимости от результата работы.Как специалист, ты будешь:- обеспечивать выполнение плана по привлечению пенсионеров на получение пенсии через Сбербанк,- консультировать пенсионеров в закрепленном отделении Пенсионного фонда России по услуге получения пенсии через Сбербанк;- оформлять заявления /заявки на открытие счета карты Сбербанк-Maestro Социальная для пенсионера.  Ты подходишь нам, если ты:- имеешь среднее/среднее профессиональное/неполное высшее/высшее образование;- желателен опыт работы с клиентами;- владеешь стандартным ПО (Microsoft Excel, Outlook)на уровне базовых операций. Личные качества:- умение самостоятельно устанавливать контакт с незнакомыми людьми;- легкость, уверенность и доброжелательность в общении;- ориентация на клиента, готовность проконсультировать, оказать помощь;- стремление к достижениям в работе, связанной с продажами, к получению дохода в зависимости от результата работы.- трудоустройство согласно ТК РФ;- гарантированный доход плюс премиальное вознаграждение;- регулярное корпоративное обучение;- ДМС, страхование от несчастных случаев и тяжелых заболеваний;- материальную помощь и социальную поддержку, корпоративную пенсионную программу;- льготные условия кредитования;- яркую и насыщенную корпоративную жизнь.',
#  '1324943')

# %%
vn = get_id_navigation(1324943)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-e6b515f0f6f7> in <module>
# ----> 1 vn = get_id_navigation(1324943)
#
# NameError: name 'get_id_navigation' is not defined

# %%
vn.

# %%
vtitles = vtab[t1 & t2].title.tolist()

# %%
vdescs = vtab[t1 & t2].description.tolist()

# %%
vids = vtab[t1 & t2].id.tolist()

# %%
vdates = vtab[t1 & t2].date.tolist()

# %%
vacancies_dict = dict(zip(vids, tuple(zip(vtitles,vdescs,vdates))))

# %%
import pickle

# %%
with open('vac.pkl','wb') as f:
    pickle.dump(vacancies_dict,f)

# %%
with open('vac.pkl','rb') as f:
    vacancies_dict = pickle.load(f)

# %%
vacids = list(vacancies_dict.keys())

# %%
# vacancies_dict.get(vacids[0])

# %%
from dbsa import Vacancy, DataAccessLayer, conn_string

# %%
dal = DataAccessLayer(conn_string)
dal.connect()

# %%
query = dal.session.query(Vacancy).filter(Vacancy.vactitle.like('%Руководитель%'))

# %%
# for record in query:                       
#     print(record.vactitle)

# %%
query
